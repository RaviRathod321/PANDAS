# %%
import pandas as pd

# %%
d = pd.read_excel('C:\\Users\\Downloads\\Data_Practice.xlsx')

# %%
pd.DataFrame(d)
# Out:
#     Unnamed: 0                             Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0          NaN  Excel Data for Practice Free Download        NaN        NaN
# 1          NaN                                    NaN        NaN        NaN
# 2          NaN                                   Date  Sales Rep      Shift
# 3          NaN                    2022-07-01 00:00:00        Ben      Night
# 4          NaN                    2022-07-01 00:00:00      Jacob        Day
# ..         ...                                    ...        ...        ...
# 86         NaN                    2022-08-29 00:00:00      Jacob        Day
# 87         NaN                    2022-08-30 00:00:00        Ben        Day
# 88         NaN                    2022-08-30 00:00:00      Jacob      Night
# 89         NaN                    2022-08-31 00:00:00        Ben      Night
# 90         NaN                    2022-08-31 00:00:00      Jacob        Day
#
# ...

# %%
pd.read_csv('C:\\Users\\Downloads\\student.csv')
# Out:
#     id         name  class  mark  gender
# 0    1     John Deo   Four    75  female
# 1    2     Max Ruin  Three    85    male
# 2    3       Arnold  Three    55    male
# 3    4   Krish Star   Four    60  female
# 4    5    John Mike   Four    60  female
# 5    6    Alex John   Four    55    male
# 6    7  My John Rob  Fifth    78    male
# 7    8       Asruid   Five    85    male
# 8    9      Tes Qry    Six    78    male
# 9   10     Big John   Four    55  female
# 10  11       Ronald    Six    89  female
# 11  12        Recky    Six    94  female
# 12  13          Kty  Seven    88  female
# 13  14         Bigy  Seven    88  female
# 14  15     Tade Row   Four    88    male
# 15  16        Gimmy   Four    88    male
# 16  17        Tumyu    Six    54    male
# 17  18        Honny   Five    75    male
# 18  19        Tinny   Nine    18    male
# 19  20       Jackly   Nine    65  female
# 20  21   Babby John   Four    69  female
# 21  22       Reggid  Seven    55  female
# ...

# %%
d ={'name':['John', 'Kevin', 'Rudolf','Edda'],
    'perc' : [99,55,48,98],
    'subjects' : ['maths', 'english', 'french', 'physics']    
}

pd.DataFrame(d)
# Out:
#      name  perc subjects
# 0    John    99    maths
# 1   Kevin    55  english
# 2  Rudolf    48   french
# 3    Edda    98  physics
